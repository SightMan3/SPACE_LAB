# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import root_mean_squared_error
from scipy.ndimage import shift
import math

# %% [markdown]
# # Data preparation

# %%
NM_data = pd.read_csv('../data/LMKS_NM_1981-2023_hour.csv')
data = pd.read_csv('../data/omni_full_1964-2022.csv')
data
# Out:
#         Unnamed: 0                time1    Rot$   IMF   PLS  IMF_PTS  PLS_PTS  \
# 0                0  1963-01-01 01:00:00  1771.0  99.0  99.0    999.0    999.0
# 1                1  1963-01-01 02:00:00  1771.0  99.0  99.0    999.0    999.0
# 2                2  1963-01-01 03:00:00  1771.0  99.0  99.0    999.0    999.0
# 3                3  1963-01-01 04:00:00  1771.0  99.0  99.0    999.0    999.0
# 4                4  1963-01-01 05:00:00  1771.0  99.0  99.0    999.0    999.0
# ...            ...                  ...     ...   ...   ...      ...      ...
# 520438      520438  2022-05-13 12:00:00  9999.0  99.0  99.0    999.0    999.0
# 520439      520439  2022-05-13 13:00:00  9999.0  99.0  99.0    999.0    999.0
# 520440      520440  2022-05-13 14:00:00  9999.0  99.0  99.0    999.0    999.0
# 520441      520441  2022-05-13 15:00:00  9999.0  99.0  99.0    999.0    999.0
# 520442      520442  2022-05-13 16:00:00  9999.0  99.0  99.0    999.0    999.0
#
#         ABS_B   F  THETA_AV  ...  F10_INDEX+48  BZ_GSE+1  BZ_GSE+2  BZ_GSE+3  \
# 0         NaN NaN       NaN  ...           NaN       NaN       NaN       NaN
# 1         NaN NaN       NaN  ...           NaN       NaN       NaN       NaN
# 2         NaN NaN       NaN  ...           NaN       NaN       NaN       NaN
# 3         NaN NaN       NaN  ...           NaN       NaN       NaN       NaN
# 4         NaN NaN       NaN  ...           NaN       NaN       NaN       NaN
# ...       ...  ..       ...  ...           ...       ...       ...       ...
# 520438    NaN NaN       NaN  ...    135.600006       NaN       NaN       NaN
# 520439    NaN NaN       NaN  ...    135.600006       NaN       NaN       NaN
# 520440    NaN NaN       NaN  ...    135.600006       NaN       NaN       NaN
# 520441    NaN NaN       NaN  ...    135.600006       NaN       NaN       NaN
# 520442    NaN NaN       NaN  ...    135.600006       NaN       NaN       NaN
#
#         BZ_GSE+4  BZ_GSE+6  BZ_GSE+8  BZ_GSE+12  BZ_GSE+24  BZ_GSE+48
# 0            NaN       NaN       NaN        NaN        NaN        NaN
# 1            NaN       NaN       NaN        NaN        NaN        NaN
# 2            NaN       NaN       NaN        NaN        NaN        NaN
# 3            NaN       NaN       NaN        NaN        NaN        NaN
# 4            NaN       NaN       NaN        NaN        NaN        NaN
# ...          ...       ...       ...        ...        ...        ...
# 520438       NaN       NaN       NaN        NaN        NaN        NaN
# 520439       NaN       NaN       NaN        NaN        NaN        NaN
# 520440       NaN       NaN       NaN        NaN        NaN        NaN
# 520441       NaN       NaN       NaN        NaN        NaN        NaN
# 520442       NaN       NaN       NaN        NaN        NaN        NaN
#
# [520443 rows x 83 columns]

# %%
NM_data.index = NM_data['Unnamed: 0']
NM_data.drop("Unnamed: 0", axis=1, inplace=True)
NM_data
# Out:
#                        H_COR
# Unnamed: 0
# 1981-12-01 00:00:00  87.2680
# 1981-12-01 01:00:00  86.9240
# 1981-12-01 02:00:00  86.8670
# 1981-12-01 03:00:00  86.4080
# 1981-12-01 04:00:00  86.5230
# ...                      ...
# 2023-07-10 19:00:00  92.4196
# 2023-07-10 20:00:00  92.4196
# 2023-07-10 21:00:00  92.4196
# 2023-07-10 22:00:00  92.4196
# 2023-07-10 23:00:00  92.4196
#
# [364728 rows x 1 columns]

# %%
NM_data.dropna(inplace=True)
NM_data.isna().sum()
# Out:
# H_COR    0
# dtype: int64

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)
data.index = data['time1']
data.drop('time1', axis=1, inplace=True)
data
# Out:
#                        Rot$   IMF   PLS  IMF_PTS  PLS_PTS  ABS_B   F  \
# time1
# 1963-01-01 01:00:00  1771.0  99.0  99.0    999.0    999.0    NaN NaN
# 1963-01-01 02:00:00  1771.0  99.0  99.0    999.0    999.0    NaN NaN
# 1963-01-01 03:00:00  1771.0  99.0  99.0    999.0    999.0    NaN NaN
# 1963-01-01 04:00:00  1771.0  99.0  99.0    999.0    999.0    NaN NaN
# 1963-01-01 05:00:00  1771.0  99.0  99.0    999.0    999.0    NaN NaN
# ...                     ...   ...   ...      ...      ...    ...  ..
# 2022-05-13 12:00:00  9999.0  99.0  99.0    999.0    999.0    NaN NaN
# 2022-05-13 13:00:00  9999.0  99.0  99.0    999.0    999.0    NaN NaN
# 2022-05-13 14:00:00  9999.0  99.0  99.0    999.0    999.0    NaN NaN
# 2022-05-13 15:00:00  9999.0  99.0  99.0    999.0    999.0    NaN NaN
# 2022-05-13 16:00:00  9999.0  99.0  99.0    999.0    999.0    NaN NaN
#
#                      THETA_AV  PHI_AV  BX_GSE  ...  F10_INDEX+48  BZ_GSE+1  \
# time1                                          ...
# 1963-01-01 01:00:00       NaN     NaN     NaN  ...           NaN       NaN
# 1963-01-01 02:00:00       NaN     NaN     NaN  ...           NaN       NaN
# 1963-01-01 03:00:00       NaN     NaN     NaN  ...           NaN       NaN
# 1963-01-01 04:00:00       NaN     NaN     NaN  ...           NaN       NaN
# 1963-01-01 05:00:00       NaN     NaN     NaN  ...           NaN       NaN
# ...                       ...     ...     ...  ...           ...       ...
# 2022-05-13 12:00:00       NaN     NaN     NaN  ...    135.600006       NaN
# 2022-05-13 13:00:00       NaN     NaN     NaN  ...    135.600006       NaN
# 2022-05-13 14:00:00       NaN     NaN     NaN  ...    135.600006       NaN
# 2022-05-13 15:00:00       NaN     NaN     NaN  ...    135.600006       NaN
# 2022-05-13 16:00:00       NaN     NaN     NaN  ...    135.600006       NaN
#
#                      BZ_GSE+2  BZ_GSE+3  BZ_GSE+4  BZ_GSE+6  BZ_GSE+8  \
# time1
# 1963-01-01 01:00:00       NaN       NaN       NaN       NaN       NaN
# 1963-01-01 02:00:00       NaN       NaN       NaN       NaN       NaN
# 1963-01-01 03:00:00       NaN       NaN       NaN       NaN       NaN
# 1963-01-01 04:00:00       NaN       NaN       NaN       NaN       NaN
# 1963-01-01 05:00:00       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2022-05-13 12:00:00       NaN       NaN       NaN       NaN       NaN
# 2022-05-13 13:00:00       NaN       NaN       NaN       NaN       NaN
# 2022-05-13 14:00:00       NaN       NaN       NaN       NaN       NaN
# 2022-05-13 15:00:00       NaN       NaN       NaN       NaN       NaN
# 2022-05-13 16:00:00       NaN       NaN       NaN       NaN       NaN
#
#                      BZ_GSE+12  BZ_GSE+24  BZ_GSE+48
# time1
# 1963-01-01 01:00:00        NaN        NaN        NaN
# 1963-01-01 02:00:00        NaN        NaN        NaN
# 1963-01-01 03:00:00        NaN        NaN        NaN
# 1963-01-01 04:00:00        NaN        NaN        NaN
# 1963-01-01 05:00:00        NaN        NaN        NaN
# ...                        ...        ...        ...
# 2022-05-13 12:00:00        NaN        NaN        NaN
# 2022-05-13 13:00:00        NaN        NaN        NaN
# 2022-05-13 14:00:00        NaN        NaN        NaN
# 2022-05-13 15:00:00        NaN        NaN        NaN
# 2022-05-13 16:00:00        NaN        NaN        NaN
#
# [520443 rows x 81 columns]

# %%
data_relevant = data[['BZ_GSE', 'V', 'N', 'DST', 'SIGMA$Bz']].loc["1995-01-01 00:00:00":]
data_relevant.isna().sum()
# Out:
# BZ_GSE       977
# V            903
# N           5586
# DST            0
# SIGMA$Bz     977
# dtype: int64

# %%
data_relevant.index = pd.to_datetime(data_relevant.index)
data_relevant_interpolated = data_relevant.interpolate(method='time')
data_relevant_interpolated.isna().sum()
# Out:
# BZ_GSE      0
# V           0
# N           0
# DST         0
# SIGMA$Bz    0
# dtype: int64

# %% [markdown]
# ## Intersection of omni data and NM data

# %%
data_relevant_interpolated.index = pd.to_datetime(data_relevant_interpolated.index)
NM_data.index = pd.to_datetime(NM_data.index)

common_index = data_relevant_interpolated.index.intersection(NM_data.index)

data_relevant_interpolated_common = data_relevant_interpolated.loc[common_index]
nm_data_common = NM_data.loc[common_index]

data_relevant_interpolated_common['NM'] = nm_data_common.iloc[:, 0]
data_relevant_interpolated = data_relevant_interpolated_common

data_relevant_interpolated.isna().sum()
# Out:
# BZ_GSE      0
# V           0
# N           0
# DST         0
# SIGMA$Bz    0
# NM          0
# dtype: int64

# %% [markdown]
# ## Data normalization

# %%
min_val = data_relevant_interpolated.min()
max_val = data_relevant_interpolated.max()

# Normalize between -1 and 1
data_relevant_interpolated_normalized = 2 * (data_relevant_interpolated - min_val) / (max_val - min_val) - 1
data_relevant_interpolated_normalized
# Out:
#                        BZ_GSE         V         N       DST  SIGMA$Bz  \
# 1995-01-01 00:00:00  0.131579 -0.818939 -0.763676  0.683367 -0.976134
# 1995-01-01 00:00:00  0.131579 -0.818939 -0.763676  0.683367 -0.976134
# 1995-01-01 01:00:00  0.149123 -0.818939 -0.727206  0.703407 -0.961814
# 1995-01-01 02:00:00  0.168860 -0.808533 -0.719912  0.715431 -0.914081
# 1995-01-01 03:00:00  0.184211 -0.814776 -0.762217  0.711423 -0.961814
# ...                       ...       ...       ...       ...       ...
# 2022-05-13 12:00:00  0.184211 -0.829344 -0.905179  0.699399 -0.904535
# 2022-05-13 13:00:00  0.184211 -0.829344 -0.905179  0.707415 -0.904535
# 2022-05-13 14:00:00  0.184211 -0.829344 -0.905179  0.711423 -0.904535
# 2022-05-13 15:00:00  0.184211 -0.829344 -0.905179  0.711423 -0.904535
# 2022-05-13 16:00:00  0.184211 -0.829344 -0.905179  0.707415 -0.904535
#
#                            NM
# 1995-01-01 00:00:00  0.412806
# 1995-01-01 00:00:00  0.412806
# 1995-01-01 01:00:00  0.405224
# 1995-01-01 02:00:00  0.403689
# 1995-01-01 03:00:00  0.399131
# ...                       ...
# 2022-05-13 12:00:00  0.714550
# 2022-05-13 13:00:00  0.715932
# 2022-05-13 14:00:00  0.717940
# 2022-05-13 15:00:00  0.707895
# 2022-05-13 16:00:00  0.701796
#
# [239877 rows x 6 columns]

# %% [markdown]
# # Regression model

# %%
data_relevant_interpolated_normalized
# Out:
#                        BZ_GSE         V         N       DST  SIGMA$Bz  \
# 1995-01-01 00:00:00  0.131579 -0.818939 -0.763676  0.683367 -0.976134
# 1995-01-01 00:00:00  0.131579 -0.818939 -0.763676  0.683367 -0.976134
# 1995-01-01 01:00:00  0.149123 -0.818939 -0.727206  0.703407 -0.961814
# 1995-01-01 02:00:00  0.168860 -0.808533 -0.719912  0.715431 -0.914081
# 1995-01-01 03:00:00  0.184211 -0.814776 -0.762217  0.711423 -0.961814
# ...                       ...       ...       ...       ...       ...
# 2022-05-13 12:00:00  0.184211 -0.829344 -0.905179  0.699399 -0.904535
# 2022-05-13 13:00:00  0.184211 -0.829344 -0.905179  0.707415 -0.904535
# 2022-05-13 14:00:00  0.184211 -0.829344 -0.905179  0.711423 -0.904535
# 2022-05-13 15:00:00  0.184211 -0.829344 -0.905179  0.711423 -0.904535
# 2022-05-13 16:00:00  0.184211 -0.829344 -0.905179  0.707415 -0.904535
#
#                            NM
# 1995-01-01 00:00:00  0.412806
# 1995-01-01 00:00:00  0.412806
# 1995-01-01 01:00:00  0.405224
# 1995-01-01 02:00:00  0.403689
# 1995-01-01 03:00:00  0.399131
# ...                       ...
# 2022-05-13 12:00:00  0.714550
# 2022-05-13 13:00:00  0.715932
# 2022-05-13 14:00:00  0.717940
# 2022-05-13 15:00:00  0.707895
# 2022-05-13 16:00:00  0.701796
#
# [239877 rows x 6 columns]

# %%
DST_shift = data_relevant_interpolated_normalized['DST'].shift(1)
DST_shift.fillna(value=0,inplace=True)
DST_shift
# Out:
# 1995-01-01 00:00:00    0.000000
# 1995-01-01 00:00:00    0.683367
# 1995-01-01 01:00:00    0.683367
# 1995-01-01 02:00:00    0.703407
# 1995-01-01 03:00:00    0.715431
#                          ...
# 2022-05-13 12:00:00    0.699399
# 2022-05-13 13:00:00    0.699399
# 2022-05-13 14:00:00    0.707415
# 2022-05-13 15:00:00    0.711423
# 2022-05-13 16:00:00    0.711423
# Name: DST, Length: 239877, dtype: float64

# %%
N = data_relevant_interpolated_normalized['N'].to_numpy()
V = data_relevant_interpolated_normalized['V'].to_numpy()
NV = N * V
Bz= data_relevant_interpolated_normalized['BZ_GSE'].to_numpy()
sigma_bz = data_relevant_interpolated_normalized['SIGMA$Bz'].to_numpy()
nm = data_relevant_interpolated_normalized['NM'].to_numpy()
DST = data_relevant_interpolated_normalized['DST'].to_numpy()

# %% [markdown]
# Definicia persistancneho modela ako linearana kombinacia zvysnych parametrov modelu FFNN.
# $$
# DST_{t+1} = DST_t + \sum_{i = 1}^{|N|} = \omega_i(\psi_i - \psi_i^{ref})
# $$
# To iste v podobe matic a vektorov.
# $$
# \vec{y} = \vec{\beta} + \mathbf{X}\vec{\omega}
# $$

# %%
y = DST_shift.to_numpy()
b = data_relevant_interpolated_normalized['DST'].to_numpy()
b.shape, y.shape
# Out:
# ((239877,), (239877,))

# %% [markdown]
# ## Vypocet matice $X$

# %%
X = []

# %%
N_mean = N.mean()
NV_mean = NV.mean()
V_mean = V.mean()
Bz_mean = Bz.mean()
sigma_bz_mean = sigma_bz.mean()
nm_mean = nm.mean()
N_mean, V_mean, Bz_mean, sigma_bz_mean, nm_mean, NV_mean
# Out:
# (np.float64(-0.9092295346299987),
#  np.float64(-0.5875355186766423),
#  np.float64(0.1771662958918724),
#  np.float64(-0.9377969344570631),
#  np.float64(0.4876614210538083),
#  np.float64(0.5285874443950322))

# %%
params = [N, V, Bz, sigma_bz, nm]

# %%
X = np.array([
    N - N_mean, V - V_mean, Bz - Bz_mean, sigma_bz - sigma_bz_mean, nm - nm_mean, NV - NV_mean
])
X.shape, X.T.shape
# Out:
# ((6, 239877), (239877, 6))

# %%
X = X.T
X.shape
# Out:
# (239877, 6)

# %% [markdown]
# ## Vypocet vah
# $$
# \vec{\omega} = (\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T(\vec{y} - \vec{\beta})
# $$

# %%
w = (np.linalg.inv(X.T @ X) @ X.T) @ (y - b)

# %%
w
# Out:
# array([ 0.06198545,  0.08515494, -0.08380987,  0.02530192,  0.00141577,
#         0.09118692])

# %% [markdown]
# ## Finalny model

# %%
persistance = b + np.sum(X*w, axis=1)

# %%
persistance
# Out:
# array([0.6842569 , 0.6842569 , 0.70271538, ..., 0.71191417, 0.71189995,
#        0.7078833 ], shape=(239877,))

# %%
# %matplotlib qt
plt.plot(y, label='DST_t+1')
plt.plot(persistance, label='prediction')
plt.legend()

# %%
mean_squared_error(y, persistance)
# Out:
# 0.0002600635399853744

# %% [markdown]
# # Shapely values
# Nech $\psi$ je nejaky parameter, $P$ je mnozina parametrov a $f : P \rightarrow DST_{t+1}$ je model a $x_0$ je jedna hodnota DST. Potom shapely hodnota parametru $\psi$ v bode $x_0$ je
# $$
# \varphi_{\psi}(x_0) = \frac{1}{|P|!} \sum_{S \subseteq P \setminus \{\psi\}} |S|!\cdot(|P| - |S| - 1)! \cdot (f(S \cup \{\psi\}) - f(S))
# $$
# Vypocet si bude vyzadovat postavit niekolko krokov.
# - Napjprv je potrebne spravit **mnozinu podmnozin** mnoziny $P$
# - Vytvorit **funkciu** ktora **vytvori model s novym poctom parametrov** na vstupe, kedze $f(S)$ bude vzdy predikcia modelu s inym poctom parametrov.
# - Skombinovat

# %% [markdown]
# ## Mnozina podmnozin $P$
# Na $S \subseteq P \setminus \{\psi\}$ sa mozeme pozerat trochu inak. V podstate to hovori ze $S$ je kazda podmnozina mnoziny $P$. Preto mozeme zapisat $S$ ako $S \subseteq \mathcal{P(\mathbf{P})}$, cize $S$ je kazda mnozina potencnej mnozinu $P$.

# %%
from itertools import chain, combinations

def powerset(iterable):
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
AllParams = [N, V, Bz, sigma_bz, nm, DST]

# %%
def power_set_minus(P, target):
    new_P = []
    for i in P:
        if i == target: continue
        else: new_P.append(i)
    power_P = list(powerset(new_P))

    return power_P

# %% [markdown]
# ## Dynamicky persistencny model

# %%
def f(P, y, b):
    '''
        P - set of parameters ([N, V, Bz,...]) (2D matrix)
        y - DST_t+1 (array)
        b - DST_t   (array)
    '''
    if not P: return np.array([])
    X = np.array([
        p - p.mean() for p in P 
    ])
    X = X.T

    w = (np.linalg.inv(X.T @ X) @ X.T) @ (y - b)

    return w

def pp(X, b, w):
    '''
        X - shape [p1 - p1_mean, p2 - p2_mean, ...]
        b - shape [DST1, DST2, DST3]
        w - weights for parameters p_1 - p_n
    '''
    X = X.T
    if len(X.shape) <= 1: return b + np.sum(X*w)
    else: return b + np.sum(X*w, axis=1)

# %%
f([], y, b)
# Out:
# array([], dtype=float64)

# %%
pp(
    np.array([N[10] - N.mean(), V[10] - V.mean(), Bz[10] - Bz.mean(), sigma_bz[10] - sigma_bz.mean(), nm[10] - nm.mean(), NV[10] - NV.mean()]),
    b[10],
    f([N, V, Bz, sigma_bz, nm, NV], y, b)
)
# Out:
# np.float64(0.6985369524786599)

# %% [markdown]
# ## Shapely values calculation

# %%
def shapely(P, target, point):
    '''
    P - set of parameters
    target - parameter for which we are calculating shapely value
    point - int value in range of the size of the parameters from P
    '''
    # Creating set of parameters without target parameter
    mask = ~np.all(P == target, axis=1)
    indexes = [i for i in range(len(mask)) if mask[i] == True]
    P_wo_target = [P[i] for i in indexes]

    # power set of set w/o target
    p_set = list(powerset(P_wo_target))[1:]

    # main loop 'sum' of the shapely formula
    summ = 0
    for sub_set in p_set:

        # finding the position of DST in every subset
        # because we need to extract DST out of the whole array as it is treated differently in comparison to other parameters
        mask_dst = ~np.all(sub_set == data_relevant_interpolated_normalized['DST'].to_numpy(), axis=1)
        indexes_dst = [i for i in range(len(mask_dst)) if mask_dst[i] == False]


        # Creating X matrix and b vector for linear model
        # based on the existance of DST in subset
        X = []
        b = []
        if not indexes_dst: # indexes_dst is empty, no dst in that subset
            X = [p[point] - p.mean() for p in sub_set]
            b = np.zeros(len(y))
        else: # DST is in the subset, we need to extract it
            X = [p[point] - p.mean() for p in sub_set[:indexes_dst[0]]]
            b = sub_set[indexes_dst[0]]
            sub_set = list(sub_set)
            del sub_set[indexes_dst[0]]

        # contribution value f(S U {i}) - f(S)
        if np.all(target != data_relevant_interpolated_normalized['DST'].to_numpy()):
            prediction          = pp(np.array(X), b[point], f(sub_set, y, b))
            X.append(target[point] - target.mean())
            sub_set = list(sub_set)
            sub_set.append(target)
            prediction_w_target = pp(np.array(X), b[point], f(sub_set, y, b))
    
            contribution = prediction_w_target - prediction
    
            # # multiplication factor |S|! * (|P| - |S| - 1)!
            mult_factor = math.factorial(len(sub_set)) * math.factorial((len(P) - len(sub_set) - 1))

            summ += mult_factor * contribution
        else:
            prediction          = pp(np.array(X), b[point], f(sub_set, y, b))
            b = target
            prediction_w_target = pp(np.array(X), b[point], f(sub_set, y, b))
    
            contribution = prediction_w_target - prediction
    
            # # multiplication factor |S|! * (|P| - |S| - 1)!
            mult_factor = math.factorial(len(sub_set)) * math.factorial((len(P) - len(sub_set) - 1))

            summ += mult_factor * contribution

    return summ/math.factorial(len(P))

def shapely2(P, p, T):
    '''
    P - set of parameters
    p - values for which we wish to calculate shapely values of every parameters
    T - target parameter, integer value from mask
    '''
    if len(P) != len(p):
        print("P and p has bad lengths")
        return

    mask = [i for i in range(len(P))]
    DST_idx = len(P)-1

    pset = power_set_minus(mask, T)

    for S in pset:

        '''
        Creating model
        '''
        X = None
        b = None
        if DST_idx in S:
            b = P[DST_idx]
            S = S[:-1]
            X = [P[i] - P[i].mean() for i in S]
        else:
            b = np.zeros(len(P[DST_idx]))
            X = [P[i] - P[i].mean() for i in S]
        
                

    return pset

# %%
shapely2(
    AllParams,
    [N[0], V[0], Bz[0], sigma_bz[0], nm[0], DST[0]],
    2
)
# Out:
# [(),
#  (0,),
#  (1,),
#  (3,),
#  (4,),
#  (5,),
#  (0, 1),
#  (0, 3),
#  (0, 4),
#  (0, 5),
#  (1, 3),
#  (1, 4),
#  (1, 5),
#  (3, 4),
#  (3, 5),
#  (4, 5),
#  (0, 1, 3),
#  (0, 1, 4),
#  (0, 1, 5),
#  (0, 3, 4),
#  (0, 3, 5),
#  (0, 4, 5),
#  (1, 3, 4),
#  (1, 3, 5),
#  (1, 4, 5),
#  (3, 4, 5),
#  (0, 1, 3, 4),
#  (0, 1, 3, 5),
#  (0, 1, 4, 5),
#  (0, 3, 4, 5),
#  (1, 3, 4, 5),
#  (0, 1, 3, 4, 5)]

# %% [markdown]
# ## Calculate shapely values for all parameters

# %%
# shapely_params_sum = []
# for p in [N, V, Bz, sigma_bz, nm, data_relevant_interpolated_normalized["DST"].to_numpy()]:
#     temp = 0
#     for i in range(len(data_relevant_interpolated_normalized["DST"].to_numpy())):
#         temp += float(shapely(
#             [N, V, Bz, sigma_bz, nm, data_relevant_interpolated_normalized["DST"].to_numpy()],
#             p,
#             i
#         ))
#     shapely_params_sum.append(temp)

# %%
# %%time
event_shapely_values = []

for p, sign in zip([N, V, Bz, sigma_bz, nm, NV, data_relevant_interpolated_normalized["DST"].to_numpy()], ["N", "V", "Bz", "sBz", "nm", "NV", "DST"]):
    temp = []
    for i in range(77200, 77500):
        print(f"{sign} -> {i}")
        temp.append(float(shapely(
                    [N, V, Bz, sigma_bz, nm, NV, data_relevant_interpolated_normalized["DST"].to_numpy()],
                    p,
                    i
                )))
    event_shapely_values.append(temp)
# Out:
# N -> 77200
# N -> 77201
# N -> 77202
# N -> 77203
# N -> 77204
# N -> 77205
# N -> 77206
# N -> 77207
# N -> 77208
# N -> 77209
# N -> 77210
# N -> 77211
# N -> 77212
# N -> 77213
# N -> 77214
# N -> 77215
# N -> 77216
# N -> 77217
# N -> 77218
# N -> 77219
# N -> 77220
# N -> 77221
# N -> 77222
# N -> 77223
# N -> 77224
# N -> 77225
# N -> 77226
# N -> 77227
# N -> 77228
# N -> 77229
# N -> 77230
# N -> 77231
# N -> 77232
# N -> 77233
# N -> 77234
# N -> 77235
# N -> 77236
# N -> 77237
# N -> 77238
# N -> 77239
# N -> 77240
# N -> 77241
# N -> 77242
# N -> 77243
# N -> 77244
# N -> 77245
# N -> 77246
# N -> 77247
# N -> 77248
# N -> 77249
# N -> 77250
# N -> 77251
# N -> 77252
# N -> 77253
# N -> 77254
# N -> 77255
# N -> 77256
# N -> 77257
# N -> 77258
# N -> 77259
# N -> 77260
# N -> 77261
# N -> 77262
# N -> 77263
# N -> 77264
# N -> 77265
# N -> 77266
# N -> 77267
# N -> 77268
# N -> 77269
# N -> 77270
# N -> 77271
# N -> 77272
# N -> 77273
# N -> 77274
# N -> 77275
# N -> 77276
# N -> 77277
# N -> 77278
# N -> 77279
# N -> 77280
# N -> 77281
# N -> 77282
# N -> 77283
# N -> 77284
# N -> 77285
# N -> 77286
# N -> 77287
# N -> 77288
# N -> 77289
# N -> 77290
# N -> 77291
# N -> 77292
# N -> 77293
# N -> 77294
# N -> 77295
# N -> 77296
# N -> 77297
# N -> 77298
# N -> 77299
# N -> 77300
# N -> 77301
# N -> 77302
# N -> 77303
# N -> 77304
# N -> 77305
# N -> 77306
# N -> 77307
# N -> 77308
# N -> 77309
# N -> 77310
# N -> 77311
# N -> 77312
# N -> 77313
# N -> 77314
# N -> 77315
# N -> 77316
# N -> 77317
# N -> 77318
# N -> 77319
# N -> 77320
# N -> 77321
# N -> 77322
# N -> 77323
# N -> 77324
# N -> 77325
# N -> 77326
# N -> 77327
# N -> 77328
# N -> 77329
# N -> 77330
# N -> 77331
# N -> 77332
# N -> 77333
# N -> 77334
# N -> 77335
# N -> 77336
# N -> 77337
# N -> 77338
# N -> 77339
# N -> 77340
# N -> 77341
# N -> 77342
# N -> 77343
# N -> 77344
# N -> 77345
# N -> 77346
# N -> 77347
# N -> 77348
# N -> 77349
# N -> 77350
# N -> 77351
# N -> 77352
# N -> 77353
# N -> 77354
# N -> 77355
# N -> 77356
# N -> 77357
# N -> 77358
# N -> 77359
# N -> 77360
# N -> 77361
# N -> 77362
# N -> 77363
# N -> 77364
# N -> 77365
# N -> 77366
# N -> 77367
# N -> 77368
# N -> 77369
# N -> 77370
# N -> 77371
# N -> 77372
# N -> 77373
# N -> 77374
# N -> 77375
# N -> 77376
# N -> 77377
# N -> 77378
# N -> 77379
# N -> 77380
# N -> 77381
# N -> 77382
# N -> 77383
# N -> 77384
# N -> 77385
# N -> 77386
# N -> 77387
# N -> 77388
# N -> 77389
# N -> 77390
# N -> 77391
# N -> 77392
# N -> 77393
# N -> 77394
# N -> 77395
# N -> 77396
# N -> 77397
# N -> 77398
# N -> 77399
# N -> 77400
# N -> 77401
# N -> 77402
# N -> 77403
# N -> 77404
# N -> 77405
# N -> 77406
# N -> 77407
# N -> 77408
# N -> 77409
# N -> 77410
# N -> 77411
# N -> 77412
# N -> 77413
# N -> 77414
# N -> 77415
# N -> 77416
# N -> 77417
# N -> 77418
# N -> 77419
# N -> 77420
# N -> 77421
# N -> 77422
# N -> 77423
# N -> 77424
# N -> 77425
# N -> 77426
# N -> 77427
# N -> 77428
# N -> 77429
# N -> 77430
# N -> 77431
# N -> 77432
# N -> 77433
# N -> 77434
# N -> 77435
# N -> 77436
# N -> 77437
# N -> 77438
# N -> 77439
# N -> 77440
# N -> 77441
# N -> 77442
# N -> 77443
# N -> 77444
# N -> 77445
# N -> 77446
# N -> 77447
# N -> 77448
# N -> 77449
# N -> 77450
# N -> 77451
# N -> 77452
# N -> 77453
# N -> 77454
# N -> 77455
# N -> 77456
# N -> 77457
# N -> 77458
# N -> 77459
# N -> 77460
# N -> 77461
# N -> 77462
# N -> 77463
# N -> 77464
# N -> 77465
# N -> 77466
# N -> 77467
# N -> 77468
# N -> 77469
# N -> 77470
# N -> 77471
# N -> 77472
# N -> 77473
# N -> 77474
# N -> 77475
# N -> 77476
# N -> 77477
# N -> 77478
# N -> 77479
# N -> 77480
# N -> 77481
# N -> 77482
# N -> 77483
# N -> 77484
# N -> 77485
# N -> 77486
# N -> 77487
# N -> 77488
# N -> 77489
# N -> 77490
# N -> 77491
# N -> 77492
# N -> 77493
# N -> 77494
# N -> 77495
# N -> 77496
# N -> 77497
# N -> 77498
# N -> 77499
# V -> 77200
# V -> 77201
# V -> 77202
# V -> 77203
# V -> 77204
# V -> 77205
# V -> 77206
# V -> 77207
# V -> 77208
# V -> 77209
# V -> 77210
# V -> 77211
# V -> 77212
# V -> 77213
# V -> 77214
# V -> 77215
# V -> 77216
# V -> 77217
# V -> 77218
# V -> 77219
# V -> 77220
# V -> 77221
# V -> 77222
# V -> 77223
# V -> 77224
# V -> 77225
# V -> 77226
# V -> 77227
# V -> 77228
# V -> 77229
# V -> 77230
# V -> 77231
# V -> 77232
# V -> 77233
# V -> 77234
# V -> 77235
# V -> 77236
# V -> 77237
# V -> 77238
# V -> 77239
# V -> 77240
# V -> 77241
# V -> 77242
# V -> 77243
# V -> 77244
# V -> 77245
# V -> 77246
# V -> 77247
# V -> 77248
# V -> 77249
# V -> 77250
# V -> 77251
# V -> 77252
# V -> 77253
# V -> 77254
# V -> 77255
# V -> 77256
# V -> 77257
# V -> 77258
# V -> 77259
# V -> 77260
# V -> 77261
# V -> 77262
# V -> 77263
# V -> 77264
# V -> 77265
# V -> 77266
# V -> 77267
# V -> 77268
# V -> 77269
# V -> 77270
# V -> 77271
# V -> 77272
# V -> 77273
# V -> 77274
# V -> 77275
# V -> 77276
# V -> 77277
# V -> 77278
# V -> 77279
# V -> 77280
# V -> 77281
# V -> 77282
# V -> 77283
# V -> 77284
# V -> 77285
# V -> 77286
# V -> 77287
# V -> 77288
# V -> 77289
# V -> 77290
# V -> 77291
# V -> 77292
# V -> 77293
# V -> 77294
# V -> 77295
# V -> 77296
# V -> 77297
# V -> 77298
# V -> 77299
# V -> 77300
# V -> 77301
# V -> 77302
# V -> 77303
# V -> 77304
# V -> 77305
# V -> 77306
# V -> 77307
# V -> 77308
# V -> 77309
# V -> 77310
# V -> 77311
# V -> 77312
# V -> 77313
# V -> 77314
# V -> 77315
# V -> 77316
# V -> 77317
# V -> 77318
# V -> 77319
# V -> 77320
# V -> 77321
# V -> 77322
# V -> 77323
# V -> 77324
# V -> 77325
# V -> 77326
# V -> 77327
# V -> 77328
# V -> 77329
# V -> 77330
# V -> 77331
# V -> 77332
# V -> 77333
# V -> 77334
# V -> 77335
# V -> 77336
# V -> 77337
# V -> 77338
# V -> 77339
# V -> 77340
# V -> 77341
# V -> 77342
# V -> 77343
# V -> 77344
# V -> 77345
# V -> 77346
# V -> 77347
# V -> 77348
# V -> 77349
# V -> 77350
# V -> 77351
# V -> 77352
# V -> 77353
# V -> 77354
# V -> 77355
# V -> 77356
# V -> 77357
# V -> 77358
# V -> 77359
# V -> 77360
# V -> 77361
# V -> 77362
# V -> 77363
# V -> 77364
# V -> 77365
# V -> 77366
# V -> 77367
# V -> 77368
# V -> 77369
# V -> 77370
# V -> 77371
# V -> 77372
# V -> 77373
# V -> 77374
# V -> 77375
# V -> 77376
# V -> 77377
# V -> 77378
# V -> 77379
# V -> 77380
# V -> 77381
# V -> 77382
# V -> 77383
# V -> 77384
# V -> 77385
# V -> 77386
# V -> 77387
# V -> 77388
# V -> 77389
# V -> 77390
# V -> 77391
# V -> 77392
# V -> 77393
# V -> 77394
# V -> 77395
# V -> 77396
# V -> 77397
# V -> 77398
# V -> 77399
# V -> 77400
# V -> 77401
# V -> 77402
# V -> 77403
# V -> 77404
# V -> 77405
# V -> 77406
# V -> 77407
# V -> 77408
# V -> 77409
# V -> 77410
# V -> 77411
# V -> 77412
# V -> 77413
# V -> 77414
# V -> 77415
# V -> 77416
# V -> 77417
# V -> 77418
# V -> 77419
# V -> 77420
# V -> 77421
# V -> 77422
# V -> 77423
# V -> 77424
# V -> 77425
# V -> 77426
# V -> 77427
# V -> 77428
# V -> 77429
# V -> 77430
# V -> 77431
# V -> 77432
# V -> 77433
# V -> 77434
# V -> 77435
# V -> 77436
# V -> 77437
# V -> 77438
# V -> 77439
# V -> 77440
# V -> 77441
# V -> 77442
# V -> 77443
# V -> 77444
# V -> 77445
# V -> 77446
# V -> 77447
# V -> 77448
# V -> 77449
# V -> 77450
# V -> 77451
# V -> 77452
# V -> 77453
# V -> 77454
# V -> 77455
# V -> 77456
# V -> 77457
# V -> 77458
# V -> 77459
# V -> 77460
# V -> 77461
# V -> 77462
# V -> 77463
# V -> 77464
# V -> 77465
# V -> 77466
# V -> 77467
# V -> 77468
# V -> 77469
# V -> 77470
# V -> 77471
# V -> 77472
# V -> 77473
# V -> 77474
# V -> 77475
# V -> 77476
# V -> 77477
# V -> 77478
# V -> 77479
# V -> 77480
# V -> 77481
# V -> 77482
# V -> 77483
# V -> 77484
# V -> 77485
# V -> 77486
# V -> 77487
# V -> 77488
# V -> 77489
# V -> 77490
# V -> 77491
# V -> 77492
# V -> 77493
# V -> 77494
# V -> 77495
# V -> 77496
# V -> 77497
# V -> 77498
# V -> 77499
# Bz -> 77200
# Bz -> 77201
# Bz -> 77202
# Bz -> 77203
# Bz -> 77204
# Bz -> 77205
# Bz -> 77206
# Bz -> 77207
# Bz -> 77208
# Bz -> 77209
# Bz -> 77210
# Bz -> 77211
# Bz -> 77212
# Bz -> 77213
# Bz -> 77214
# Bz -> 77215
# Bz -> 77216
# Bz -> 77217
# Bz -> 77218
# Bz -> 77219
# Bz -> 77220
# Bz -> 77221
# Bz -> 77222
# Bz -> 77223
# Bz -> 77224
# Bz -> 77225
# Bz -> 77226
# Bz -> 77227
# Bz -> 77228
# Bz -> 77229
# Bz -> 77230
# Bz -> 77231
# Bz -> 77232
# Bz -> 77233
# Bz -> 77234
# Bz -> 77235
# Bz -> 77236
# Bz -> 77237
# Bz -> 77238
# Bz -> 77239
# Bz -> 77240
# Bz -> 77241
# Bz -> 77242
# Bz -> 77243
# Bz -> 77244
# Bz -> 77245
# Bz -> 77246
# Bz -> 77247
# Bz -> 77248
# Bz -> 77249
# Bz -> 77250
# Bz -> 77251
# Bz -> 77252
# Bz -> 77253
# Bz -> 77254
# Bz -> 77255
# Bz -> 77256
# Bz -> 77257
# Bz -> 77258
# Bz -> 77259
# Bz -> 77260
# Bz -> 77261
# Bz -> 77262
# Bz -> 77263
# Bz -> 77264
# Bz -> 77265
# Bz -> 77266
# Bz -> 77267
# Bz -> 77268
# Bz -> 77269
# Bz -> 77270
# Bz -> 77271
# Bz -> 77272
# Bz -> 77273
# Bz -> 77274
# Bz -> 77275
# Bz -> 77276
# Bz -> 77277
# Bz -> 77278
# Bz -> 77279
# Bz -> 77280
# Bz -> 77281
# Bz -> 77282
# Bz -> 77283
# Bz -> 77284
# Bz -> 77285
# Bz -> 77286
# Bz -> 77287
# Bz -> 77288
# Bz -> 77289
# Bz -> 77290
# Bz -> 77291
# Bz -> 77292
# Bz -> 77293
# Bz -> 77294
# Bz -> 77295
# Bz -> 77296
# Bz -> 77297
# Bz -> 77298
# Bz -> 77299
# Bz -> 77300
# Bz -> 77301
# Bz -> 77302
# Bz -> 77303
# Bz -> 77304
# Bz -> 77305
# Bz -> 77306
# Bz -> 77307
# Bz -> 77308
# Bz -> 77309
# Bz -> 77310
# Bz -> 77311
# Bz -> 77312
# Bz -> 77313
# Bz -> 77314
# Bz -> 77315
# Bz -> 77316
# Bz -> 77317
# Bz -> 77318
# Bz -> 77319
# Bz -> 77320
# Bz -> 77321
# Bz -> 77322
# Bz -> 77323
# Bz -> 77324
# Bz -> 77325
# Bz -> 77326
# Bz -> 77327
# Bz -> 77328
# Bz -> 77329
# Bz -> 77330
# Bz -> 77331
# Bz -> 77332
# Bz -> 77333
# Bz -> 77334
# Bz -> 77335
# Bz -> 77336
# Bz -> 77337
# Bz -> 77338
# Bz -> 77339
# Bz -> 77340
# Bz -> 77341
# Bz -> 77342
# Bz -> 77343
# Bz -> 77344
# Bz -> 77345
# Bz -> 77346
# Bz -> 77347
# Bz -> 77348
# Bz -> 77349
# Bz -> 77350
# Bz -> 77351
# Bz -> 77352
# Bz -> 77353
# Bz -> 77354
# Bz -> 77355
# Bz -> 77356
# Bz -> 77357
# Bz -> 77358
# Bz -> 77359
# Bz -> 77360
# Bz -> 77361
# Bz -> 77362
# Bz -> 77363
# Bz -> 77364
# Bz -> 77365
# Bz -> 77366
# Bz -> 77367
# Bz -> 77368
# Bz -> 77369
# Bz -> 77370
# Bz -> 77371
# Bz -> 77372
# Bz -> 77373
# Bz -> 77374
# Bz -> 77375
# Bz -> 77376
# Bz -> 77377
# Bz -> 77378
# Bz -> 77379
# Bz -> 77380
# Bz -> 77381
# Bz -> 77382
# Bz -> 77383
# Bz -> 77384
# Bz -> 77385
# Bz -> 77386
# Bz -> 77387
# Bz -> 77388
# Bz -> 77389
# Bz -> 77390
# Bz -> 77391
# Bz -> 77392
# Bz -> 77393
# Bz -> 77394
# Bz -> 77395
# Bz -> 77396
# Bz -> 77397
# Bz -> 77398
# Bz -> 77399
# Bz -> 77400
# Bz -> 77401
# Bz -> 77402
# Bz -> 77403
# Bz -> 77404
# Bz -> 77405
# Bz -> 77406
# Bz -> 77407
# Bz -> 77408
# Bz -> 77409
# Bz -> 77410
# Bz -> 77411
# Bz -> 77412
# Bz -> 77413
# Bz -> 77414
# Bz -> 77415
# Bz -> 77416
# Bz -> 77417
# Bz -> 77418
# Bz -> 77419
# Bz -> 77420
# Bz -> 77421
# Bz -> 77422
# Bz -> 77423
# Bz -> 77424
# Bz -> 77425
# Bz -> 77426
# Bz -> 77427
# Bz -> 77428
# Bz -> 77429
# Bz -> 77430
# Bz -> 77431
# Bz -> 77432
# Bz -> 77433
# Bz -> 77434
# Bz -> 77435
# Bz -> 77436
# Bz -> 77437
# Bz -> 77438
# Bz -> 77439
# Bz -> 77440
# Bz -> 77441
# Bz -> 77442
# Bz -> 77443
# Bz -> 77444
# Bz -> 77445
# Bz -> 77446
# Bz -> 77447
# Bz -> 77448
# Bz -> 77449
# Bz -> 77450
# Bz -> 77451
# Bz -> 77452
# Bz -> 77453
# Bz -> 77454
# Bz -> 77455
# Bz -> 77456
# Bz -> 77457
# Bz -> 77458
# Bz -> 77459
# Bz -> 77460
# Bz -> 77461
# Bz -> 77462
# Bz -> 77463
# Bz -> 77464
# Bz -> 77465
# Bz -> 77466
# Bz -> 77467
# Bz -> 77468
# Bz -> 77469
# Bz -> 77470
# Bz -> 77471
# Bz -> 77472
# Bz -> 77473
# Bz -> 77474
# Bz -> 77475
# Bz -> 77476
# Bz -> 77477
# Bz -> 77478
# Bz -> 77479
# Bz -> 77480
# Bz -> 77481
# Bz -> 77482
# Bz -> 77483
# Bz -> 77484
# Bz -> 77485
# Bz -> 77486
# Bz -> 77487
# Bz -> 77488
# Bz -> 77489
# Bz -> 77490
# Bz -> 77491
# Bz -> 77492
# Bz -> 77493
# Bz -> 77494
# Bz -> 77495
# Bz -> 77496
# Bz -> 77497
# Bz -> 77498
# Bz -> 77499
# sBz -> 77200
# sBz -> 77201
# sBz -> 77202
# sBz -> 77203
# sBz -> 77204
# sBz -> 77205
# sBz -> 77206
# sBz -> 77207
# sBz -> 77208
# sBz -> 77209
# sBz -> 77210
# sBz -> 77211
# sBz -> 77212
# sBz -> 77213
# sBz -> 77214
# sBz -> 77215
# sBz -> 77216
# sBz -> 77217
# sBz -> 77218
# sBz -> 77219
# sBz -> 77220
# sBz -> 77221
# sBz -> 77222
# sBz -> 77223
# sBz -> 77224
# sBz -> 77225
# sBz -> 77226
# sBz -> 77227
# sBz -> 77228
# sBz -> 77229
# sBz -> 77230
# sBz -> 77231
# sBz -> 77232
# sBz -> 77233
# sBz -> 77234
# sBz -> 77235
# sBz -> 77236
# sBz -> 77237
# sBz -> 77238
# sBz -> 77239
# sBz -> 77240
# sBz -> 77241
# sBz -> 77242
# sBz -> 77243
# sBz -> 77244
# sBz -> 77245
# sBz -> 77246
# sBz -> 77247
# sBz -> 77248
# sBz -> 77249
# sBz -> 77250
# sBz -> 77251
# sBz -> 77252
# sBz -> 77253
# sBz -> 77254
# sBz -> 77255
# sBz -> 77256
# sBz -> 77257
# sBz -> 77258
# sBz -> 77259
# sBz -> 77260
# sBz -> 77261
# sBz -> 77262
# sBz -> 77263
# sBz -> 77264
# sBz -> 77265
# sBz -> 77266
# sBz -> 77267
# sBz -> 77268
# sBz -> 77269
# sBz -> 77270
# sBz -> 77271
# sBz -> 77272
# sBz -> 77273
# sBz -> 77274
# sBz -> 77275
# sBz -> 77276
# sBz -> 77277
# sBz -> 77278
# sBz -> 77279
# sBz -> 77280
# sBz -> 77281
# sBz -> 77282
# sBz -> 77283
# sBz -> 77284
# sBz -> 77285
# sBz -> 77286
# sBz -> 77287
# sBz -> 77288
# sBz -> 77289
# sBz -> 77290
# sBz -> 77291
# sBz -> 77292
# sBz -> 77293
# sBz -> 77294
# sBz -> 77295
# sBz -> 77296
# sBz -> 77297
# sBz -> 77298
# sBz -> 77299
# sBz -> 77300
# sBz -> 77301
# sBz -> 77302
# sBz -> 77303
# sBz -> 77304
# sBz -> 77305
# sBz -> 77306
# sBz -> 77307
# sBz -> 77308
# sBz -> 77309
# sBz -> 77310
# sBz -> 77311
# sBz -> 77312
# sBz -> 77313
# sBz -> 77314
# sBz -> 77315
# sBz -> 77316
# sBz -> 77317
# sBz -> 77318
# sBz -> 77319
# sBz -> 77320
# sBz -> 77321
# sBz -> 77322
# sBz -> 77323
# sBz -> 77324
# sBz -> 77325
# sBz -> 77326
# sBz -> 77327
# sBz -> 77328
# sBz -> 77329
# sBz -> 77330
# sBz -> 77331
# sBz -> 77332
# sBz -> 77333
# sBz -> 77334
# sBz -> 77335
# sBz -> 77336
# sBz -> 77337
# sBz -> 77338
# sBz -> 77339
# sBz -> 77340
# sBz -> 77341
# sBz -> 77342
# sBz -> 77343
# sBz -> 77344
# sBz -> 77345
# sBz -> 77346
# sBz -> 77347
# sBz -> 77348
# sBz -> 77349
# sBz -> 77350
# sBz -> 77351
# sBz -> 77352
# sBz -> 77353
# sBz -> 77354
# sBz -> 77355
# sBz -> 77356
# sBz -> 77357
# sBz -> 77358
# sBz -> 77359
# sBz -> 77360
# sBz -> 77361
# sBz -> 77362
# sBz -> 77363
# sBz -> 77364
# sBz -> 77365
# sBz -> 77366
# sBz -> 77367
# sBz -> 77368
# sBz -> 77369
# sBz -> 77370
# sBz -> 77371
# sBz -> 77372
# sBz -> 77373
# sBz -> 77374
# sBz -> 77375
# sBz -> 77376
# sBz -> 77377
# sBz -> 77378
# sBz -> 77379
# sBz -> 77380
# sBz -> 77381
# sBz -> 77382
# sBz -> 77383
# sBz -> 77384
# sBz -> 77385
# sBz -> 77386
# sBz -> 77387
# sBz -> 77388
# sBz -> 77389
# sBz -> 77390
# sBz -> 77391
# sBz -> 77392
# sBz -> 77393
# sBz -> 77394
# sBz -> 77395
# sBz -> 77396
# sBz -> 77397
# sBz -> 77398
# sBz -> 77399
# sBz -> 77400
# sBz -> 77401
# sBz -> 77402
# sBz -> 77403
# sBz -> 77404
# sBz -> 77405
# sBz -> 77406
# sBz -> 77407
# sBz -> 77408
# sBz -> 77409
# sBz -> 77410
# sBz -> 77411
# sBz -> 77412
# sBz -> 77413
# sBz -> 77414
# sBz -> 77415
# sBz -> 77416
# sBz -> 77417
# sBz -> 77418
# sBz -> 77419
# sBz -> 77420
# sBz -> 77421
# sBz -> 77422
# sBz -> 77423
# sBz -> 77424
# sBz -> 77425
# sBz -> 77426
# sBz -> 77427
# sBz -> 77428
# sBz -> 77429
# sBz -> 77430
# sBz -> 77431
# sBz -> 77432
# sBz -> 77433
# sBz -> 77434
# sBz -> 77435
# sBz -> 77436
# sBz -> 77437
# sBz -> 77438
# sBz -> 77439
# sBz -> 77440
# sBz -> 77441
# sBz -> 77442
# sBz -> 77443
# sBz -> 77444
# sBz -> 77445
# sBz -> 77446
# sBz -> 77447
# sBz -> 77448
# sBz -> 77449
# sBz -> 77450
# sBz -> 77451
# sBz -> 77452
# sBz -> 77453
# sBz -> 77454
# sBz -> 77455
# sBz -> 77456
# sBz -> 77457
# sBz -> 77458
# sBz -> 77459
# sBz -> 77460
# sBz -> 77461
# sBz -> 77462
# sBz -> 77463
# sBz -> 77464
# sBz -> 77465
# sBz -> 77466
# sBz -> 77467
# sBz -> 77468
# sBz -> 77469
# sBz -> 77470
# sBz -> 77471
# sBz -> 77472
# sBz -> 77473
# sBz -> 77474
# sBz -> 77475
# sBz -> 77476
# sBz -> 77477
# sBz -> 77478
# sBz -> 77479
# sBz -> 77480
# sBz -> 77481
# sBz -> 77482
# sBz -> 77483
# sBz -> 77484
# sBz -> 77485
# sBz -> 77486
# sBz -> 77487
# sBz -> 77488
# sBz -> 77489
# sBz -> 77490
# sBz -> 77491
# sBz -> 77492
# sBz -> 77493
# sBz -> 77494
# sBz -> 77495
# sBz -> 77496
# sBz -> 77497
# sBz -> 77498
# sBz -> 77499
# nm -> 77200
# nm -> 77201
# nm -> 77202
# nm -> 77203
# nm -> 77204
# nm -> 77205
# nm -> 77206
# nm -> 77207
# nm -> 77208
# nm -> 77209
# nm -> 77210
# nm -> 77211
# nm -> 77212
# nm -> 77213
# nm -> 77214
# nm -> 77215
# nm -> 77216
# nm -> 77217
# nm -> 77218
# nm -> 77219
# nm -> 77220
# nm -> 77221
# nm -> 77222
# nm -> 77223
# nm -> 77224
# nm -> 77225
# nm -> 77226
# nm -> 77227
# nm -> 77228
# nm -> 77229
# nm -> 77230
# nm -> 77231
# nm -> 77232
# nm -> 77233
# nm -> 77234
# nm -> 77235
# nm -> 77236
# nm -> 77237
# nm -> 77238
# nm -> 77239
# nm -> 77240
# nm -> 77241
# nm -> 77242
# nm -> 77243
# nm -> 77244
# nm -> 77245
# nm -> 77246
# nm -> 77247
# nm -> 77248
# nm -> 77249
# nm -> 77250
# nm -> 77251
# nm -> 77252
# nm -> 77253
# nm -> 77254
# nm -> 77255
# nm -> 77256
# nm -> 77257
# nm -> 77258
# nm -> 77259
# nm -> 77260
# nm -> 77261
# nm -> 77262
# nm -> 77263
# nm -> 77264
# nm -> 77265
# nm -> 77266
# nm -> 77267
# nm -> 77268
# nm -> 77269
# nm -> 77270
# nm -> 77271
# nm -> 77272
# nm -> 77273
# nm -> 77274
# nm -> 77275
# nm -> 77276
# nm -> 77277
# nm -> 77278
# nm -> 77279
# nm -> 77280
# nm -> 77281
# nm -> 77282
# nm -> 77283
# nm -> 77284
# nm -> 77285
# nm -> 77286
# nm -> 77287
# nm -> 77288
# nm -> 77289
# nm -> 77290
# nm -> 77291
# nm -> 77292
# nm -> 77293
# nm -> 77294
# nm -> 77295
# nm -> 77296
# nm -> 77297
# nm -> 77298
# nm -> 77299
# nm -> 77300
# nm -> 77301
# nm -> 77302
# nm -> 77303
# nm -> 77304
# nm -> 77305
# nm -> 77306
# nm -> 77307
# nm -> 77308
# nm -> 77309
# nm -> 77310
# nm -> 77311
# nm -> 77312
# nm -> 77313
# nm -> 77314
# nm -> 77315
# nm -> 77316
# nm -> 77317
# nm -> 77318
# nm -> 77319
# nm -> 77320
# nm -> 77321
# nm -> 77322
# nm -> 77323
# nm -> 77324
# nm -> 77325
# nm -> 77326
# nm -> 77327
# nm -> 77328
# nm -> 77329
# nm -> 77330
# nm -> 77331
# nm -> 77332
# nm -> 77333
# nm -> 77334
# nm -> 77335
# nm -> 77336
# nm -> 77337
# nm -> 77338
# nm -> 77339
# nm -> 77340
# nm -> 77341
# nm -> 77342
# nm -> 77343
# nm -> 77344
# nm -> 77345
# nm -> 77346
# nm -> 77347
# nm -> 77348
# nm -> 77349
# nm -> 77350
# nm -> 77351
# nm -> 77352
# nm -> 77353
# nm -> 77354
# nm -> 77355
# nm -> 77356
# nm -> 77357
# nm -> 77358
# nm -> 77359
# nm -> 77360
# nm -> 77361
# nm -> 77362
# nm -> 77363
# nm -> 77364
# nm -> 77365
# nm -> 77366
# nm -> 77367
# nm -> 77368
# nm -> 77369
# nm -> 77370
# nm -> 77371
# nm -> 77372
# nm -> 77373
# nm -> 77374
# nm -> 77375
# nm -> 77376
# nm -> 77377
# nm -> 77378
# nm -> 77379
# nm -> 77380
# nm -> 77381
# nm -> 77382
# nm -> 77383
# nm -> 77384
# nm -> 77385
# nm -> 77386
# nm -> 77387
# nm -> 77388
# nm -> 77389
# nm -> 77390
# nm -> 77391
# nm -> 77392
# nm -> 77393
# nm -> 77394
# nm -> 77395
# nm -> 77396
# nm -> 77397
# nm -> 77398
# nm -> 77399
# nm -> 77400
# nm -> 77401
# nm -> 77402
# nm -> 77403
# nm -> 77404
# nm -> 77405
# nm -> 77406
# nm -> 77407
# nm -> 77408
# nm -> 77409
# nm -> 77410
# nm -> 77411
# nm -> 77412
# nm -> 77413
# nm -> 77414
# nm -> 77415
# nm -> 77416
# nm -> 77417
# nm -> 77418
# nm -> 77419
# nm -> 77420
# nm -> 77421
# nm -> 77422
# nm -> 77423
# nm -> 77424
# nm -> 77425
# nm -> 77426
# nm -> 77427
# nm -> 77428
# nm -> 77429
# nm -> 77430
# nm -> 77431
# nm -> 77432
# nm -> 77433
# nm -> 77434
# nm -> 77435
# nm -> 77436
# nm -> 77437
# nm -> 77438
# nm -> 77439
# nm -> 77440
# nm -> 77441
# nm -> 77442
# nm -> 77443
# nm -> 77444
# nm -> 77445
# nm -> 77446
# nm -> 77447
# nm -> 77448
# nm -> 77449
# nm -> 77450
# nm -> 77451
# nm -> 77452
# nm -> 77453
# nm -> 77454
# nm -> 77455
# nm -> 77456
# nm -> 77457
# nm -> 77458
# nm -> 77459
# nm -> 77460
# nm -> 77461
# nm -> 77462
# nm -> 77463
# nm -> 77464
# nm -> 77465
# nm -> 77466
# nm -> 77467
# nm -> 77468
# nm -> 77469
# nm -> 77470
# nm -> 77471
# nm -> 77472
# nm -> 77473
# nm -> 77474
# nm -> 77475
# nm -> 77476
# nm -> 77477
# nm -> 77478
# nm -> 77479
# nm -> 77480
# nm -> 77481
# nm -> 77482
# nm -> 77483
# nm -> 77484
# nm -> 77485
# nm -> 77486
# nm -> 77487
# nm -> 77488
# nm -> 77489
# nm -> 77490
# nm -> 77491
# nm -> 77492
# nm -> 77493
# nm -> 77494
# nm -> 77495
# nm -> 77496
# nm -> 77497
# nm -> 77498
# nm -> 77499
# NV -> 77200
# NV -> 77201
# NV -> 77202
# NV -> 77203
# NV -> 77204
# NV -> 77205
# NV -> 77206
# NV -> 77207
# NV -> 77208
# NV -> 77209
# NV -> 77210
# NV -> 77211
# NV -> 77212
# NV -> 77213
# NV -> 77214
# NV -> 77215
# NV -> 77216
# NV -> 77217
# NV -> 77218
# NV -> 77219
# NV -> 77220
# NV -> 77221
# NV -> 77222
# NV -> 77223
# NV -> 77224
# NV -> 77225
# NV -> 77226
# NV -> 77227
# NV -> 77228
# NV -> 77229
# NV -> 77230
# NV -> 77231
# NV -> 77232
# NV -> 77233
# NV -> 77234
# NV -> 77235
# NV -> 77236
# NV -> 77237
# NV -> 77238
# NV -> 77239
# NV -> 77240
# NV -> 77241
# NV -> 77242
# NV -> 77243
# NV -> 77244
# NV -> 77245
# NV -> 77246
# NV -> 77247
# NV -> 77248
# NV -> 77249
# NV -> 77250
# NV -> 77251
# NV -> 77252
# NV -> 77253
# NV -> 77254
# NV -> 77255
# NV -> 77256
# NV -> 77257
# NV -> 77258
# NV -> 77259
# NV -> 77260
# NV -> 77261
# NV -> 77262
# NV -> 77263
# NV -> 77264
# NV -> 77265
# NV -> 77266
# NV -> 77267
# NV -> 77268
# NV -> 77269
# NV -> 77270
# NV -> 77271
# NV -> 77272
# NV -> 77273
# NV -> 77274
# NV -> 77275
# NV -> 77276
# NV -> 77277
# NV -> 77278
# NV -> 77279
# NV -> 77280
# NV -> 77281
# NV -> 77282
# NV -> 77283
# NV -> 77284
# NV -> 77285
# NV -> 77286
# NV -> 77287
# NV -> 77288
# NV -> 77289
# NV -> 77290
# NV -> 77291
# NV -> 77292
# NV -> 77293
# NV -> 77294
# NV -> 77295
# NV -> 77296
# NV -> 77297
# NV -> 77298
# NV -> 77299
# NV -> 77300
# NV -> 77301
# NV -> 77302
# NV -> 77303
# NV -> 77304
# NV -> 77305
# NV -> 77306
# NV -> 77307
# NV -> 77308
# NV -> 77309
# NV -> 77310
# NV -> 77311
# NV -> 77312
# NV -> 77313
# NV -> 77314
# NV -> 77315
# NV -> 77316
# NV -> 77317
# NV -> 77318
# NV -> 77319
# NV -> 77320
# NV -> 77321
# NV -> 77322
# NV -> 77323
# NV -> 77324
# NV -> 77325
# NV -> 77326
# NV -> 77327
# NV -> 77328
# NV -> 77329
# NV -> 77330
# NV -> 77331
# NV -> 77332
# NV -> 77333
# NV -> 77334
# NV -> 77335
# NV -> 77336
# NV -> 77337
# NV -> 77338
# NV -> 77339
# NV -> 77340
# NV -> 77341
# NV -> 77342
# NV -> 77343
# NV -> 77344
# NV -> 77345
# NV -> 77346
# NV -> 77347
# NV -> 77348
# NV -> 77349
# NV -> 77350
# NV -> 77351
# NV -> 77352
# NV -> 77353
# NV -> 77354
# NV -> 77355
# NV -> 77356
# NV -> 77357
# NV -> 77358
# NV -> 77359
# NV -> 77360
# NV -> 77361
# NV -> 77362
# NV -> 77363
# NV -> 77364
# NV -> 77365
# NV -> 77366
# NV -> 77367
# NV -> 77368
# NV -> 77369
# NV -> 77370
# NV -> 77371
# NV -> 77372
# NV -> 77373
# NV -> 77374
# NV -> 77375
# NV -> 77376
# NV -> 77377
# NV -> 77378
# NV -> 77379
# NV -> 77380
# NV -> 77381
# NV -> 77382
# NV -> 77383
# NV -> 77384
# NV -> 77385
# NV -> 77386
# NV -> 77387
# NV -> 77388
# NV -> 77389
# NV -> 77390
# NV -> 77391
# NV -> 77392
# NV -> 77393
# NV -> 77394
# NV -> 77395
# NV -> 77396
# NV -> 77397
# NV -> 77398
# NV -> 77399
# NV -> 77400
# NV -> 77401
# NV -> 77402
# NV -> 77403
# NV -> 77404
# NV -> 77405
# NV -> 77406
# NV -> 77407
# NV -> 77408
# NV -> 77409
# NV -> 77410
# NV -> 77411
# NV -> 77412
# NV -> 77413
# NV -> 77414
# NV -> 77415
# NV -> 77416
# NV -> 77417
# NV -> 77418
# NV -> 77419
# NV -> 77420
# NV -> 77421
# NV -> 77422
# NV -> 77423
# NV -> 77424
# NV -> 77425
# NV -> 77426
# NV -> 77427
# NV -> 77428
# NV -> 77429
# NV -> 77430
# NV -> 77431
# NV -> 77432
# NV -> 77433
# NV -> 77434
# NV -> 77435
# NV -> 77436
# NV -> 77437
# NV -> 77438
# NV -> 77439
# NV -> 77440
# NV -> 77441
# NV -> 77442
# NV -> 77443
# NV -> 77444
# NV -> 77445
# NV -> 77446
# NV -> 77447
# NV -> 77448
# NV -> 77449
# NV -> 77450
# NV -> 77451
# NV -> 77452
# NV -> 77453
# NV -> 77454
# NV -> 77455
# NV -> 77456
# NV -> 77457
# NV -> 77458
# NV -> 77459
# NV -> 77460
# NV -> 77461
# NV -> 77462
# NV -> 77463
# NV -> 77464
# NV -> 77465
# NV -> 77466
# NV -> 77467
# NV -> 77468
# NV -> 77469
# NV -> 77470
# NV -> 77471
# NV -> 77472
# NV -> 77473
# NV -> 77474
# NV -> 77475
# NV -> 77476
# NV -> 77477
# NV -> 77478
# NV -> 77479
# NV -> 77480
# NV -> 77481
# NV -> 77482
# NV -> 77483
# NV -> 77484
# NV -> 77485
# NV -> 77486
# NV -> 77487
# NV -> 77488
# NV -> 77489
# NV -> 77490
# NV -> 77491
# NV -> 77492
# NV -> 77493
# NV -> 77494
# NV -> 77495
# NV -> 77496
# NV -> 77497
# NV -> 77498
# NV -> 77499
# DST -> 77200
# DST -> 77201
# DST -> 77202
# DST -> 77203
# DST -> 77204
# DST -> 77205
# DST -> 77206
# DST -> 77207
# DST -> 77208
# DST -> 77209
# DST -> 77210
# DST -> 77211
# DST -> 77212
# DST -> 77213
# DST -> 77214
# DST -> 77215
# DST -> 77216
# DST -> 77217
# DST -> 77218
# DST -> 77219
# DST -> 77220
# DST -> 77221
# DST -> 77222
# DST -> 77223
# DST -> 77224
# DST -> 77225
# DST -> 77226
# DST -> 77227
# DST -> 77228
# DST -> 77229
# DST -> 77230
# DST -> 77231
# DST -> 77232
# DST -> 77233
# DST -> 77234
# DST -> 77235
# DST -> 77236
# DST -> 77237
# DST -> 77238
# DST -> 77239
# DST -> 77240
# DST -> 77241
# DST -> 77242
# DST -> 77243
# DST -> 77244
# DST -> 77245
# DST -> 77246
# DST -> 77247
# DST -> 77248
# DST -> 77249
# DST -> 77250
# DST -> 77251
# DST -> 77252
# DST -> 77253
# DST -> 77254
# DST -> 77255
# DST -> 77256
# DST -> 77257
# DST -> 77258
# DST -> 77259
# DST -> 77260
# DST -> 77261
# DST -> 77262
# DST -> 77263
# DST -> 77264
# DST -> 77265
# DST -> 77266
# DST -> 77267
# DST -> 77268
# DST -> 77269
# DST -> 77270
# DST -> 77271
# DST -> 77272
# DST -> 77273
# DST -> 77274
# DST -> 77275
# DST -> 77276
# DST -> 77277
# DST -> 77278
# DST -> 77279
# DST -> 77280
# DST -> 77281
# DST -> 77282
# DST -> 77283
# DST -> 77284
# DST -> 77285
# DST -> 77286
# DST -> 77287
# DST -> 77288
# DST -> 77289
# DST -> 77290
# DST -> 77291
# DST -> 77292
# DST -> 77293
# DST -> 77294
# DST -> 77295
# DST -> 77296
# DST -> 77297
# DST -> 77298
# DST -> 77299
# DST -> 77300
# DST -> 77301
# DST -> 77302
# DST -> 77303
# DST -> 77304
# DST -> 77305
# DST -> 77306
# DST -> 77307
# DST -> 77308
# DST -> 77309
# DST -> 77310
# DST -> 77311
# DST -> 77312
# DST -> 77313
# DST -> 77314
# DST -> 77315
# DST -> 77316
# DST -> 77317
# DST -> 77318
# DST -> 77319
# DST -> 77320
# DST -> 77321
# DST -> 77322
# DST -> 77323
# DST -> 77324
# DST -> 77325
# DST -> 77326
# DST -> 77327
# DST -> 77328
# DST -> 77329
# DST -> 77330
# DST -> 77331
# DST -> 77332
# DST -> 77333
# DST -> 77334
# DST -> 77335
# DST -> 77336
# DST -> 77337
# DST -> 77338
# DST -> 77339
# DST -> 77340
# DST -> 77341
# DST -> 77342
# DST -> 77343
# DST -> 77344
# DST -> 77345
# DST -> 77346
# DST -> 77347
# DST -> 77348
# DST -> 77349
# DST -> 77350
# DST -> 77351
# DST -> 77352
# DST -> 77353
# DST -> 77354
# DST -> 77355
# DST -> 77356
# DST -> 77357
# DST -> 77358
# DST -> 77359
# DST -> 77360
# DST -> 77361
# DST -> 77362
# DST -> 77363
# DST -> 77364
# DST -> 77365
# DST -> 77366
# DST -> 77367
# DST -> 77368
# DST -> 77369
# DST -> 77370
# DST -> 77371
# DST -> 77372
# DST -> 77373
# DST -> 77374
# DST -> 77375
# DST -> 77376
# DST -> 77377
# DST -> 77378
# DST -> 77379
# DST -> 77380
# DST -> 77381
# DST -> 77382
# DST -> 77383
# DST -> 77384
# DST -> 77385
# DST -> 77386
# DST -> 77387
# DST -> 77388
# DST -> 77389
# DST -> 77390
# DST -> 77391
# DST -> 77392
# DST -> 77393
# DST -> 77394
# DST -> 77395
# DST -> 77396
# DST -> 77397
# DST -> 77398
# DST -> 77399
# DST -> 77400
# DST -> 77401
# DST -> 77402
# DST -> 77403
# DST -> 77404
# DST -> 77405
# DST -> 77406
# DST -> 77407
# DST -> 77408
# DST -> 77409
# DST -> 77410
# DST -> 77411
# DST -> 77412
# DST -> 77413
# DST -> 77414
# DST -> 77415
# DST -> 77416
# DST -> 77417
# DST -> 77418
# DST -> 77419
# DST -> 77420
# DST -> 77421
# DST -> 77422
# DST -> 77423
# DST -> 77424
# DST -> 77425
# DST -> 77426
# DST -> 77427
# DST -> 77428
# DST -> 77429
# DST -> 77430
# DST -> 77431
# DST -> 77432
# DST -> 77433
# DST -> 77434
# DST -> 77435
# DST -> 77436
# DST -> 77437
# DST -> 77438
# DST -> 77439
# DST -> 77440
# DST -> 77441
# DST -> 77442
# DST -> 77443
# DST -> 77444
# DST -> 77445
# DST -> 77446
# DST -> 77447
# DST -> 77448
# DST -> 77449
# DST -> 77450
# DST -> 77451
# DST -> 77452
# DST -> 77453
# DST -> 77454
# DST -> 77455
# DST -> 77456
# DST -> 77457
# DST -> 77458
# DST -> 77459
# DST -> 77460
# DST -> 77461
# DST -> 77462
# DST -> 77463
# DST -> 77464
# DST -> 77465
# DST -> 77466
# DST -> 77467
# DST -> 77468
# DST -> 77469
# DST -> 77470
# DST -> 77471
# DST -> 77472
# DST -> 77473
# DST -> 77474
# DST -> 77475
# DST -> 77476
# DST -> 77477
# DST -> 77478
# DST -> 77479
# DST -> 77480
# DST -> 77481
# DST -> 77482
# DST -> 77483
# DST -> 77484
# DST -> 77485
# DST -> 77486
# DST -> 77487
# DST -> 77488
# DST -> 77489
# DST -> 77490
# DST -> 77491
# DST -> 77492
# DST -> 77493
# DST -> 77494
# DST -> 77495
# DST -> 77496
# DST -> 77497
# DST -> 77498
# DST -> 77499
# CPU times: total: 49min 30s
# Wall time: 31min 43s

# %%
NM_shapely = []
for i in range(len(data_relevant_interpolated_normalized)):
    temp.append(float(shapely(
                [N, V, Bz, sigma_bz, nm, NV, data_relevant_interpolated_normalized["DST"].to_numpy()],
                nm,
                i
            )))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 3
#       1 NM_shapely = []
#       2 for i in range(len(data_relevant_interpolated_normalized)):
# ----> 3     temp.append(float(shapely(
#       4                 [N, V, Bz, sigma_bz, nm, NV, data_relevant_interpolated_normalized["DST"].to_numpy()],
#       5                 nm,
#       6                 i
#       7             )))
#
# Cell In[31], line 44, in shapely(P, target, point)
#      42 sub_set = list(sub_set)
#      43 sub_set.append(target)
# ---> 44 prediction_w_target = pp(np.array(X), b[point], f(sub_set, y, b))
#      46 contribution = prediction_w_target - prediction
#      48 # # multiplication factor |S|! * (|P| - |S| - 1)!
#
# Cell In[28], line 17, in pp(X, b, w)
#      13     w = (np.linalg.inv(X.T @ X) @ X.T) @ (y - b)
#      15     return w
# ---> 17 def pp(X, b, w):
#      18     '''
#      19         X - shape [p1 - p1_mean, p2 - p2_mean, ...]
#      20         b - shape [DST1, DST2, DST3]
#      21         w - weights for parameters p_1 - p_n
#      22     '''
#      23     X = X.T
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plotting results

# %%
string_params = ["N", "V", "Bz", "sigma Bz", "NM", "NV", "DST_t"]
fig, axs = plt.subplots(len(event_shapely_values))
for i in range(len(axs)):
    axs[i].plot(event_shapely_values[i])
    axs[i].set_title(string_params[i])

# %%
event_shapely_values_mean = np.mean(event_shapely_values, axis=1)
plt.bar(string_params, event_shapely_values_mean)
# Out:
# <BarContainer object of 7 artists>

# %%
event_shapely_values_mean
# Out:
# array([-4.13817701e-04, -9.10952208e-03,  1.14700502e-03, -2.52452403e-04,
#        -1.83445254e-02, -7.88439880e-03,  4.71692062e-01])

# %%
data_relevant_interpolated_normalized['DST'].iloc[77200:77500].plot()
# Out:
# <Axes: >

# %%
len(data_relevant_interpolated_normalized)
# Out:
# 239877
